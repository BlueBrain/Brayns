# %% [markdown]
# # Take a snapshot

# %%
from brayns import Client
brayns = Client('localhost:8200')

# %%
brayns.image(size=(400,300))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x300 at 0x7FC39402D850>
